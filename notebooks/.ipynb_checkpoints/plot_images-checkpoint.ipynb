# %%
import sys 

sys.path.append("..")

from costum_arild.source import data_processing

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## Gaula 2009

# %%
# read a large image to see how it is in the network
# same method as used in run_prediction.py

big_image_path = r'/home/saeid/phd/segmentation/dataset/new_rivers/gaula_2009/image/33-2-462-206-13.tif'

images = data_processing.divide_image(big_image_path, big_image_path, image_size=512, do_crop=False,
                                  do_overlap=False)

# %%
image_n = 100
print(f'mean of image intensity is {images[image_n].data.mean()}')
plt.imshow(images[image_n].data)

# %% [markdown]
# ## Gaula 1963

# %%
# read a large image to see how it is in the network
# same method as used in run_prediction.py

big_image_path = r'/home/saeid/phd/segmentation/dataset/large images/images/gaula_1963/33-2-462-207-22.tif'

images = data_processing.divide_image(big_image_path, big_image_path, image_size=512, do_crop=False,
                                  do_overlap=False)

# %%
image_n = 100
print(f'mean of image intensity is {images[image_n].data.mean()}')
plt.imshow(images[image_n].data)
# Out:
# mean of image intensity is 86.68197631835938
